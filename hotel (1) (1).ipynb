# %%
import pandas as pd
import requests
import os
import time
from dotenv import load_dotenv
from pymongo import MongoClient

# envs
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
# geo location
cities = [
    {"city": "London", "lat": 51.5074, "lng": -0.1278},
    {"city": "Manchester", "lat": 53.4808, "lng": -2.2426},
    {"city": "Birmingham", "lat": 52.4862, "lng": -1.8904},
    {"city": "Glasgow", "lat": 55.8642, "lng": -4.2518},
    {"city": "Liverpool", "lat": 53.4084, "lng": -2.9916},
    {"city": "Leeds", "lat": 53.8008, "lng": -1.5491},
    {"city": "Edinburgh", "lat": 55.9533, "lng": -3.1883},
    {"city": "Bristol", "lat": 51.4545, "lng": -2.5879},
    {"city": "Sheffield", "lat": 53.3811, "lng": -1.4701}
]


GRID_SIZE = 11 #grid
STEP_KM = 2.0       
RADIUS = 3000       # in meters , used with geo locations


def km_to_deg(km):
    
    return km / 111.0

def generate_grid(center_lat, center_lng, grid_size, step_km):
    #grid around of city center
    coords = []
    offset = grid_size // 2
    lat_step = km_to_deg(step_km)
    lng_step = km_to_deg(step_km)
    for i in range(grid_size): 
        for j in range(grid_size):
            lat = center_lat + (i - offset) * lat_step
            lng = center_lng + (j - offset) * lng_step
            coords.append((lat, lng))
    return coords

unique_place_ids = set()
hotels_data = []

def fetch_hotels(lat, lng, city_name):
    #API using for hotels data 
    
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = { #pramaters which is I need in data 
        "location": f"{lat},{lng}",
        "radius": RADIUS,
        "type": "lodging",
        "key": GOOGLE_API_KEY
    }

    while True:
        response = requests.get(url, params=params)
        data = response.json()

        for result in data.get("results", []):
            place_id = result.get("place_id")
            if place_id and place_id not in unique_place_ids:
                unique_place_ids.add(place_id)
                hotel = {
                    "name": result.get("name"),
                    "city": city_name,
                    "address": result.get("vicinity"),
                    "latitude": result.get("geometry", {}).get("location", {}).get("lat"),
                    "longitude": result.get("geometry", {}).get("location", {}).get("lng"),
                    "google_rating": result.get("rating"),
                    "google_review_count": result.get("user_ratings_total"),
                    "place_id": place_id
                }
                hotels_data.append(hotel)

        next_token = data.get("next_page_token")
        if next_token:
            time.sleep(3)
            params = {"pagetoken": next_token, "key": GOOGLE_API_KEY}
        else:
            break

# hotel scanning in circle 
for city in cities:
    print(f"\n Scanning {city['city']}")
    grid_points = generate_grid(city["lat"], city["lng"], GRID_SIZE, STEP_KM)
    for lat, lng in grid_points:
        fetch_hotels(lat, lng, city["city"])
        print(f"Scanned ({lat:.4f}, {lng:.4f}) — Total unique: {len(hotels_data)}")
        if len(hotels_data) >= 1500:
            break
        time.sleep(1.2)
    if len(hotels_data) >= 1500:
        break

def get_place_details(place_id):
    #Fethcing google ratings with api 
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {
        "place_id": place_id,
        "fields": "rating,user_ratings_total",
        "key": GOOGLE_API_KEY
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        result = data.get("result", {})
        return result.get("rating"), result.get("user_ratings_total")
    except:
        return None, None

# filling missing ratings
df = pd.DataFrame(hotels_data)
missing = df[df["google_rating"].isna() | df["google_review_count"].isna()]
print(f"\n Fixing {len(missing)} missing ratings...")

for index, row in missing.iterrows():
    rating, review_count = get_place_details(row["place_id"])
    df.at[index, "google_rating"] = rating
    df.at[index, "google_review_count"] = review_count
    print(f"✔️ {row['name']} — rating: {rating}, reviews: {review_count}")
    time.sleep(1.2)
# Out:
#  Scanning London
# Scanned (51.4173, -0.2179) — Total unique: 60
# Scanned (51.4173, -0.1999) — Total unique: 71
# Scanned (51.4173, -0.1819) — Total unique: 87
# Scanned (51.4173, -0.1638) — Total unique: 113
# Scanned (51.4173, -0.1458) — Total unique: 136
# Scanned (51.4173, -0.1278) — Total unique: 154
# Scanned (51.4173, -0.1098) — Total unique: 175
# Scanned (51.4173, -0.0918) — Total unique: 194
# Scanned (51.4173, -0.0737) — Total unique: 216
# Scanned (51.4173, -0.0557) — Total unique: 231
# Scanned (51.4173, -0.0377) — Total unique: 247
# Scanned (51.4353, -0.2179) — Total unique: 266
# Scanned (51.4353, -0.1999) — Total unique: 276
# Scanned (51.4353, -0.1819) — Total unique: 282
# Scanned (51.4353, -0.1638) — Total unique: 296
# Scanned (51.4353, -0.1458) — Total unique: 311
# Scanned (51.4353, -0.1278) — Total unique: 322
# Scanned (51.4353, -0.1098) — Total unique: 334
# Scanned (51.4353, -0.0918) — Total unique: 344
# Scanned (51.4353, -0.0737) — Total unique: 353
# Scanned (51.4353, -0.0557) — Total unique: 360
# Scanned (51.4353, -0.0377) — Total unique: 367
# Scanned (51.4533, -0.2179) — Total unique: 405
# Scanned (51.4533, -0.1999) — Total unique: 422
# Scanned (51.4533, -0.1819) — Total unique: 427
# Scanned (51.4533, -0.1638) — Total unique: 434
# Scanned (51.4533, -0.1458) — Total unique: 448
# Scanned (51.4533, -0.1278) — Total unique: 460
# Scanned (51.4533, -0.1098) — Total unique: 475
# Scanned (51.4533, -0.0918) — Total unique: 488
# Scanned (51.4533, -0.0737) — Total unique: 495
# Scanned (51.4533, -0.0557) — Total unique: 504
# Scanned (51.4533, -0.0377) — Total unique: 519
# Scanned (51.4714, -0.2179) — Total unique: 566
# Scanned (51.4714, -0.1999) — Total unique: 591
# Scanned (51.4714, -0.1819) — Total unique: 601
# Scanned (51.4714, -0.1638) — Total unique: 631
# Scanned (51.4714, -0.1458) — Total unique: 649
# Scanned (51.4714, -0.1278) — Total unique: 658
# Scanned (51.4714, -0.1098) — Total unique: 678
# Scanned (51.4714, -0.0918) — Total unique: 692
# Scanned (51.4714, -0.0737) — Total unique: 700
# Scanned (51.4714, -0.0557) — Total unique: 717
# Scanned (51.4714, -0.0377) — Total unique: 736
# Scanned (51.4894, -0.2179) — Total unique: 751
# Scanned (51.4894, -0.1999) — Total unique: 758
# Scanned (51.4894, -0.1819) — Total unique: 771
# Scanned (51.4894, -0.1638) — Total unique: 780
# Scanned (51.4894, -0.1458) — Total unique: 800
# Scanned (51.4894, -0.1278) — Total unique: 812
# Scanned (51.4894, -0.1098) — Total unique: 826
# Scanned (51.4894, -0.0918) — Total unique: 841
# Scanned (51.4894, -0.0737) — Total unique: 853
# Scanned (51.4894, -0.0557) — Total unique: 873
# Scanned (51.4894, -0.0377) — Total unique: 892
# Scanned (51.5074, -0.2179) — Total unique: 906
# Scanned (51.5074, -0.1999) — Total unique: 914
# Scanned (51.5074, -0.1819) — Total unique: 921
# Scanned (51.5074, -0.1638) — Total unique: 928
# Scanned (51.5074, -0.1458) — Total unique: 934
# Scanned (51.5074, -0.1278) — Total unique: 935
# Scanned (51.5074, -0.1098) — Total unique: 937
# Scanned (51.5074, -0.0918) — Total unique: 943
# Scanned (51.5074, -0.0737) — Total unique: 951
# Scanned (51.5074, -0.0557) — Total unique: 960
# Scanned (51.5074, -0.0377) — Total unique: 976
# Scanned (51.5254, -0.2179) — Total unique: 1003
# Scanned (51.5254, -0.1999) — Total unique: 1018
# Scanned (51.5254, -0.1819) — Total unique: 1027
# Scanned (51.5254, -0.1638) — Total unique: 1031
# Scanned (51.5254, -0.1458) — Total unique: 1038
# Scanned (51.5254, -0.1278) — Total unique: 1039
# Scanned (51.5254, -0.1098) — Total unique: 1039
# Scanned (51.5254, -0.0918) — Total unique: 1043
# Scanned (51.5254, -0.0737) — Total unique: 1046
# Scanned (51.5254, -0.0557) — Total unique: 1050
# Scanned (51.5254, -0.0377) — Total unique: 1056
# Scanned (51.5434, -0.2179) — Total unique: 1112
# Scanned (51.5434, -0.1999) — Total unique: 1126
# Scanned (51.5434, -0.1819) — Total unique: 1145
# Scanned (51.5434, -0.1638) — Total unique: 1162
# Scanned (51.5434, -0.1458) — Total unique: 1180
# Scanned (51.5434, -0.1278) — Total unique: 1187
# Scanned (51.5434, -0.1098) — Total unique: 1190
# Scanned (51.5434, -0.0918) — Total unique: 1199
# Scanned (51.5434, -0.0737) — Total unique: 1223
# Scanned (51.5434, -0.0557) — Total unique: 1242
# Scanned (51.5434, -0.0377) — Total unique: 1274
# Scanned (51.5615, -0.2179) — Total unique: 1307
# Scanned (51.5615, -0.1999) — Total unique: 1307
# Scanned (51.5615, -0.1819) — Total unique: 1311
# Scanned (51.5615, -0.1638) — Total unique: 1327
# Scanned (51.5615, -0.1458) — Total unique: 1337
# Scanned (51.5615, -0.1278) — Total unique: 1354
# Scanned (51.5615, -0.1098) — Total unique: 1359
# Scanned (51.5615, -0.0918) — Total unique: 1368
# Scanned (51.5615, -0.0737) — Total unique: 1376
# Scanned (51.5615, -0.0557) — Total unique: 1400
# Scanned (51.5615, -0.0377) — Total unique: 1414
# Scanned (51.5795, -0.2179) — Total unique: 1446
# Scanned (51.5795, -0.1999) — Total unique: 1460
# Scanned (51.5795, -0.1819) — Total unique: 1474
# Scanned (51.5795, -0.1638) — Total unique: 1490
# Scanned (51.5795, -0.1458) — Total unique: 1515
#
#  Fixing 318 missing ratings...
# ✔️ Circle Self Catering House — rating: None, reviews: None
# ✔️ Executive Roomspace - The Courtyard — rating: None, reviews: None
# ✔️ iHotel Choice — rating: None, reviews: None
# ✔️ Executive Roomspace Limited — rating: None, reviews: None
# ✔️ Monteacute House Ltd — rating: None, reviews: None
# ✔️ Wimbledon Short Stays - Savona Close — rating: None, reviews: None
# ✔️ E&M — rating: None, reviews: None
# ✔️ Carolia Westminster Hotel Limited — rating: None, reviews: None
# ✔️ Brickyard Cottage — rating: None, reviews: None
# ✔️ First Serve West Wimbledon — rating: None, reviews: None
# ✔️ Royal Thames Suites — rating: None, reviews: None
# ✔️ Antoinette Hotel — rating: None, reviews: None
# ✔️ Kings Lodge — rating: None, reviews: None
# ✔️ IKS Hotels Ltd — rating: None, reviews: None
# ✔️ Arbury court — rating: None, reviews: None
# ✔️ Oackly House — rating: None, reviews: None
# ✔️ Em&Aur Maisonette — rating: None, reviews: None
# ✔️ Sun of Love Villas — rating: None, reviews: None
# ✔️ Maritim Hotels — rating: None, reviews: None
# ✔️ Meadowside — rating: None, reviews: None
# ✔️ Roomhub — rating: None, reviews: None
# ✔️ LAURENTA PROPERTIES — rating: None, reviews: None
# ✔️ Luxury Lifestyle Experts — rating: None, reviews: None
# ✔️ Falcon and Sachz ltd — rating: None, reviews: None
# ✔️ HolidayWeb — rating: None, reviews: None
# ✔️ Place — rating: None, reviews: None
# ✔️ Lovely Liberty Double Rooms — rating: None, reviews: None
# ✔️ md stays — rating: None, reviews: None
# ✔️ Jaydens Hotel Suppliers Ltd — rating: None, reviews: None
# ✔️ JODELIE BUILDING — rating: None, reviews: None
# ✔️ Tooting Stays — rating: None, reviews: None
# ✔️ Tooting Grove — rating: None, reviews: None
# ✔️ Faancy Stayz — rating: None, reviews: None
# ✔️ ZAFATSTIC.com — rating: None, reviews: None
# ✔️ NKY Apartment — rating: None, reviews: None
# ✔️ Southside Self Catering Apartments — rating: None, reviews: None
# ✔️ Mitcham Lane Ltd — rating: None, reviews: None
# ✔️ Masum hotel — rating: None, reviews: None
# ✔️ Hotel — rating: None, reviews: None
# ✔️ Jared’s house — rating: None, reviews: None
# ✔️ WelcomeStay Tooting Accommodation — rating: None, reviews: None
# ✔️ Hybrid Resi - Mitcham — rating: None, reviews: None
# ✔️ Hollzys yard — rating: None, reviews: None
# ✔️ Bibiana — rating: None, reviews: None
# ✔️ Malikstays Serviced Accomodations — rating: None, reviews: None
# ✔️ Amplify Growth Solutions — rating: None, reviews: None
# ✔️ covent gardens — rating: None, reviews: None
# ✔️ Charles Richardson Short Lets — rating: None, reviews: None
# ✔️ Bedford-Park-Hotel — rating: None, reviews: None
# ✔️ Luxury Chichester Caravan Seaside Retreat — rating: None, reviews: None
# ✔️ Care Management Group — rating: None, reviews: None
# ✔️ Care Management Group Ltd — rating: None, reviews: None
# ✔️ KHarlowcrm — rating: None, reviews: None
# ✔️ Supranational Hotels — rating: None, reviews: None
# ✔️ Streatham Comfort Stay — rating: None, reviews: None
# ✔️ Meu lugar — rating: None, reviews: None
# ✔️ Max and Rachel's — rating: None, reviews: None
# ✔️ Deluxe Swifthouse Apartments — rating: None, reviews: None
# ✔️ Kevin’s — rating: None, reviews: None
# ✔️ Revenue by Design Ltd — rating: None, reviews: None
# ✔️ Heaven Aspasia — rating: None, reviews: None
# ✔️ Karounwitemi — rating: None, reviews: None
# ✔️ Choice Care Domitillary Agency — rating: None, reviews: None
# ✔️ Boracay Apartment — rating: None, reviews: None
# ✔️ Spectacular London Stays — rating: None, reviews: None
# ✔️ White Location — rating: None, reviews: None
# ✔️ lyall — rating: None, reviews: None
# ✔️ Chartte,Airb&b — rating: None, reviews: None
# ✔️ Dartford Young Living — rating: None, reviews: None
# ✔️ Soft & Bright - Thornton Heath — rating: None, reviews: None
# ✔️ Cute & Cosy Holiday Flat - Thornton Heath — rating: None, reviews: None
# ✔️ Itchenore — rating: None, reviews: None
# ✔️ Almuslim — rating: None, reviews: None
# ✔️ N3wspot Shared Homes — rating: None, reviews: None
# ✔️ Re.Studios Sydenham Limited — rating: None, reviews: None
# ✔️ Birkbeck Beckenham — rating: None, reviews: None
# ✔️ 伦敦民宿 — rating: None, reviews: None
# ✔️ Oceans Apart — rating: None, reviews: None
# ✔️ Madam Elizabeth Motel & Resort — rating: None, reviews: None
# ✔️ TOWER SUITES — rating: None, reviews: None
# ✔️ Spacious rooms in Foresthill — rating: None, reviews: None
# ✔️ Care Elite Ltd — rating: None, reviews: None
# ✔️ Ghana Holiday Villas — rating: None, reviews: None
# ✔️ Cedars Road Student House — rating: None, reviews: None
# ✔️ BB Beckenham Hotel Apartments — rating: None, reviews: None
# ✔️ Bed and breakfast — rating: None, reviews: None
# ✔️ Prayas residential hostel — rating: None, reviews: None
# ✔️ Biltfaden Twenewaa Ltd — rating: None, reviews: None
# ✔️ Hotel — rating: None, reviews: None
# ✔️ Lewisham Foodbank — rating: None, reviews: None
# ✔️ Lewisham Serviced Apartments — rating: None, reviews: None
# ✔️ Lewisham 2 Bed Serviced Apartment (London) — rating: None, reviews: None
# ✔️ cozy studio flat — rating: None, reviews: None
# ✔️ EDINBURGH AT HOME — rating: None, reviews: None
# ✔️ Margaret's Airbnb — rating: None, reviews: None
# ✔️ WD Lettings — rating: None, reviews: None
# ✔️ Charming Home With Patio Close to Wimbledon Park by Underthedoormat — rating: None, reviews: None
# ✔️ B&B — rating: None, reviews: None
# ✔️ Pereira House — rating: None, reviews: None
# ✔️ Hotel Analyst — rating: None, reviews: None
# ✔️ Odyssey C S S T Ltd — rating: None, reviews: None
# ✔️ Wabi Sabi House — rating: None, reviews: None
# ✔️ Balham B&B — rating: None, reviews: None
# ✔️ Travelodge hotel — rating: None, reviews: None
# ✔️ Vacances Holiday Flat — rating: None, reviews: None
# ✔️ Island staycation — rating: None, reviews: None
# ✔️ Lovely Apartment Balham F4 — rating: None, reviews: None
# ✔️ Spacious Deluxe Room with Garden F6 — rating: None, reviews: None
# ✔️ Double Room - Balham Guest House F1 — rating: None, reviews: None
# ✔️ Farm house — rating: None, reviews: None
# ✔️ Kho — rating: None, reviews: None
# ✔️ Womenza — rating: None, reviews: None
# ✔️ Lexton Gardens Holiday Letting — rating: None, reviews: None
# ✔️ JUNGLE — rating: None, reviews: None
# ✔️ Holiday Apartment - Christchurch Road — rating: None, reviews: None
# ✔️ SUPERB SNUG studio sleeps 2 south london — rating: None, reviews: None
# ✔️ The Brixton Chillax — rating: None, reviews: None
# ✔️ The Coach House — rating: None, reviews: None
# ✔️ On The Market Leasehold — rating: None, reviews: None
# ✔️ My Serviced Space Serviced Accommodation Brixton — rating: None, reviews: None
# ✔️ eb hause — rating: None, reviews: None
# ✔️ 74A helix rd Brixton London sw22js — rating: None, reviews: None
# ✔️ Brother — rating: None, reviews: None
# ✔️ Mount Adon Park Residential Units — rating: None, reviews: None
# ✔️ SMI Luxury Accommodations — rating: None, reviews: None
# ✔️ Qties Luxury Home — rating: None, reviews: None
# ✔️ Hamilton Lodge — rating: None, reviews: None
# ✔️ Cabrini home — rating: None, reviews: None
# ✔️ Meu Hotel — rating: None, reviews: None
# ✔️ Ayurveda Beach Resorts Trivandrum — rating: None, reviews: None
# ✔️ Sky High Manali Holidays — rating: None, reviews: None
# ✔️ 홈스테이 — rating: None, reviews: None
# ✔️ The Blake Room — rating: None, reviews: None
# ✔️ Cosmedoctor — rating: None, reviews: None
# ✔️ Lynne Court — rating: None, reviews: None
# ✔️ depto london — rating: None, reviews: None
# ✔️ Maison anglais — rating: None, reviews: None
# ✔️ Prapa navaratnarasa — rating: None, reviews: None
# ✔️ appartment for rent — rating: None, reviews: None
# ✔️ Ciudad de México — rating: None, reviews: None
# ✔️ walex — rating: None, reviews: None
# ✔️ Apartment Perfect For 4 Guests — rating: None, reviews: None
# ✔️ Characterful 2 double bedroom Fulham cottage. — rating: None, reviews: None
# ✔️ Chic London Apartments — rating: None, reviews: None
# ✔️ Hallin Cottage — rating: None, reviews: None
# ✔️ Cindy Knuth — rating: None, reviews: None
# ✔️ Loxi Hospitality — rating: None, reviews: None
# ✔️ Cambria Lodge — rating: None, reviews: None
# ✔️ Park Lodge, Putney — rating: None, reviews: None
# ✔️ Study Living — rating: None, reviews: None
# ✔️ The London Townhouse — rating: None, reviews: None
# ✔️ Hamilton ct — rating: None, reviews: None
# ✔️ ada — rating: None, reviews: None
# ✔️ Ellie — rating: None, reviews: None
# ✔️ Supreme Riverview London — rating: None, reviews: None
# ✔️ Eliane House Londres — rating: None, reviews: None
# ✔️ Apartmentstay — rating: None, reviews: None
# ✔️ 361 Queenstown Road — rating: None, reviews: None
# ✔️ Buyacaravan — rating: None, reviews: None
# ✔️ Unser Hotel — rating: None, reviews: None
# ✔️ MY UNI DIGS — rating: None, reviews: None
# ✔️ Hotel Bell Tent Ltd — rating: None, reviews: None
# ✔️ Christopher London place — rating: None, reviews: None
# ✔️ The Heart Yard — rating: None, reviews: None
# ✔️ Rockcliffe — rating: None, reviews: None
# ✔️ WeNest Property Solutions Ltd — rating: None, reviews: None
# ✔️ Rose Villa — rating: None, reviews: None
# ✔️ Brixton Oasis — rating: None, reviews: None
# ✔️ Qties Beautiful Abode — rating: None, reviews: None
# ✔️ Hotel — rating: None, reviews: None
# ✔️ My Sky Secret Garden — rating: None, reviews: None
# ✔️ Nocleg — rating: None, reviews: None
# ✔️ 숙소! — rating: None, reviews: None
# ✔️ Grove Court, Southwark, London — rating: None, reviews: None
# ✔️ JEORGE KANNING — rating: None, reviews: None
# ✔️ FBS HOMES- Brixton — rating: None, reviews: None
# ✔️ London Zona 2, Easy travel — rating: None, reviews: None
# ✔️ Bull Yard — rating: None, reviews: None
# ✔️ Coolvoyage Destinations — rating: None, reviews: None
# ✔️ Arnold Dobson House — rating: None, reviews: None
# ✔️ Pearsall Terrace — rating: None, reviews: None
# ✔️ THE UK LONDON AGENCY LTD — rating: None, reviews: None
# ✔️ JOIVY at VITA London — rating: None, reviews: None
# ✔️ The North End Road Residence — rating: None, reviews: None
# ✔️ Regents Court Apartment — rating: None, reviews: None
# ✔️ Lovely Holiday Apartment — rating: None, reviews: None
# ✔️ Victoria Hall Student Accommodation — rating: None, reviews: None
# ✔️ Victorian Superior Property — rating: None, reviews: None
# ✔️ Zubair khan — rating: None, reviews: None
# ✔️ SereneLodgingsLTD — rating: None, reviews: None
# ✔️ 5 Benhill Road HOUSE — rating: None, reviews: None
# ✔️ Chedyne's — rating: None, reviews: None
# ✔️ Candle Light Catering Ltd — rating: None, reviews: None
# ✔️ sim lodge ostello pino simeone — rating: None, reviews: None
# ✔️ BonaStays — rating: None, reviews: None
# ✔️ Fbs Homes- New Cross — rating: None, reviews: None
# ✔️ Accident Repair Centere — rating: None, reviews: None
# ✔️ FBS Homes- South Bermondsey — rating: None, reviews: None
# ✔️ Riverside Lets — rating: None, reviews: None
# ✔️ Serviced Rooms — rating: None, reviews: None
# ✔️ Reya Properties — rating: None, reviews: None
# ✔️ Mia’s former room — rating: None, reviews: None
# ✔️ LONDON&SUNNY — rating: None, reviews: None
# ✔️ Key Supporting workers Apartments — rating: None, reviews: None
# ✔️ Pritchard 4 Bedrooms — rating: None, reviews: None
# ✔️ Princelet Town Room & Board — rating: None, reviews: None
# ✔️ Generous Apartments — rating: None, reviews: None
# ✔️ Portobello Two — rating: None, reviews: None
# ✔️ Peace-full Flat In Cricklewood — rating: None, reviews: None
# ✔️ Portobello Apartment — rating: None, reviews: None
# ✔️ Luxury Finchley Rd Apartments — rating: None, reviews: None
# ✔️ All Counties Park Home Refurbishments — rating: None, reviews: None
# ✔️ Atlantica Suites NW — rating: None, reviews: None
# ✔️ Xklusif Fashion — rating: None, reviews: None
# ✔️ Urban Stay — rating: None, reviews: None
# ✔️ Design Apts Belsize Park — rating: None, reviews: None
# ✔️ Britannia Warren Street — rating: None, reviews: None
# ✔️ Shoredich & Aparments — rating: None, reviews: None
# ✔️ Shoreditch & Old Street Apartment — rating: None, reviews: None
# ✔️ Comfortable Room for Guest — rating: None, reviews: None
# ✔️ Still Life Old Street Executive — rating: None, reviews: None
# ✔️ Hancock Luxury — rating: None, reviews: None
# ✔️ Central Superior Apartments — rating: None, reviews: None
# ✔️ Central London Premium Angel Apartments — rating: None, reviews: None
# ✔️ TheLodgingRooms - Clerkenwell — rating: None, reviews: None
# ✔️ Angel Support Living Ltd — rating: None, reviews: None
# ✔️ Mailbox 4 U — rating: None, reviews: None
# ✔️ Dyibar Joherol belaa — rating: None, reviews: None
# ✔️ Booska shire jilacow — rating: None, reviews: None
# ✔️ Pu — rating: None, reviews: None
# ✔️ Mottakin বাসা — rating: None, reviews: None
# ✔️ Hospedaje londres octubre — rating: None, reviews: None
# ✔️ Miri — rating: None, reviews: None
# ✔️ Plan Studio — rating: None, reviews: None
# ✔️ Bridgeman House — rating: None, reviews: None
# ✔️ Serviced Apartment Summit — rating: None, reviews: None
# ✔️ KOUTIQUE — rating: None, reviews: None
# ✔️ Room in Guest Room - Limehouse Townhomes: Modern Spacious Serviced En-suite Room With a Garden View — rating: None, reviews: None
# ✔️ Zozy Clitterhouse — rating: None, reviews: None
# ✔️ Collaldra School of Writing — rating: None, reviews: None
# ✔️ Camden Studios — rating: None, reviews: None
# ✔️ Totalstay — rating: None, reviews: None
# ✔️ Butler House — rating: None, reviews: None
# ✔️ York Way Spacious Apartments — rating: None, reviews: None
# ✔️ 1810 Georgian House — rating: None, reviews: None
# ✔️ Luxury Apartments King's Cross St Pancras — rating: None, reviews: None
# ✔️ Sacred Mastery Yoga — rating: None, reviews: None
# ✔️ Kent House — rating: None, reviews: None
# ✔️ Paradise apartaments — rating: None, reviews: None
# ✔️ Peelers — rating: None, reviews: None
# ✔️ ゲストスウィートグレーター — rating: None, reviews: None
# ✔️ Bunkhouse — rating: None, reviews: None
# ✔️ Botanical Sanctuary In Stoke Newington — rating: None, reviews: None
# ✔️ Walthamstow Studio Apartment — rating: None, reviews: None
# ✔️ Yakov Chaim Grossman — rating: None, reviews: None
# ✔️ Trendy Oasis in Stoke Newington — rating: None, reviews: None
# ✔️ Ace — rating: None, reviews: None
# ✔️ Alexander Apartments London — rating: None, reviews: None
# ✔️ Atlantic View - Barra Holiday Cottage — rating: None, reviews: None
# ✔️ sevko — rating: None, reviews: None
# ✔️ London Affordable Serviced Apartment With High Speed Broadband !! — rating: None, reviews: None
# ✔️ Gloria house Belgrade road — rating: None, reviews: None
# ✔️ The Garden Hotel — rating: None, reviews: None
# ✔️ Cosy Room in London Fields — rating: None, reviews: None
# ✔️ Room4U — rating: None, reviews: None
# ✔️ Roomtolet — rating: None, reviews: None
# ✔️ Luxury Appartements — rating: None, reviews: None
# ✔️ The Roseate Villa Bath — rating: None, reviews: None
# ✔️ Immo Chalets — rating: None, reviews: None
# ✔️ London Apartaments — rating: None, reviews: None
# ✔️ New Place — rating: None, reviews: None
# ✔️ The Brentano Suite — rating: None, reviews: None
# ✔️ Optimal Luxury Stay Hendon — rating: None, reviews: None
# ✔️ A hotel — rating: None, reviews: None
# ✔️ Gold Suite — rating: None, reviews: None
# ✔️ Luxury Shortlets — rating: None, reviews: None
# ✔️ Parkway Concierge — rating: None, reviews: None
# ✔️ Comfy 1BDR — rating: None, reviews: None
# ✔️ Maison Londres — rating: None, reviews: None
# ✔️ Cineplex Short Term Rental Properties London — rating: None, reviews: None
# ✔️ Suites by Rehoboth | Hendon Station — rating: None, reviews: None
# ✔️ Haven Lodge — rating: None, reviews: None
# ✔️ homely - North London Apartments Hendon — rating: None, reviews: None
# ✔️ COVER GARDEN LONDON — rating: None, reviews: None
# ✔️ Stanley House — rating: None, reviews: None
# ✔️ Algarve Getaways — rating: None, reviews: None
# ✔️ Derf Guol — rating: None, reviews: None
# ✔️ Bethney green — rating: None, reviews: None
# ✔️ Cat hotel — rating: None, reviews: None
# ✔️ Ledger Lodge — rating: None, reviews: None
# ✔️ ela kent — rating: None, reviews: None
# ✔️ Дім анг — rating: None, reviews: None
# ✔️ Villa Dei Fiori — rating: None, reviews: None
# ✔️ The Studio — rating: None, reviews: None
# ✔️ London Luxury Serviced Apartments — rating: None, reviews: None
# ✔️ Sir Gonda Lodge — rating: None, reviews: None
# ✔️ Rose and Crown Hotel — rating: None, reviews: None
# ✔️ Yanella’s house — rating: None, reviews: None
# ✔️ Alojamento Audrey — rating: None, reviews: None
# ✔️ London Town House — rating: None, reviews: None
# ✔️ Levens Mansions — rating: None, reviews: None
# ✔️ Midhurst Mansion — rating: None, reviews: None
# ✔️ Nuffield Lodge — rating: None, reviews: None
# ✔️ Modern Victorian Gem in Muswell Hill, North London — rating: None, reviews: None
# ✔️ Lu_Casa_Londres — rating: None, reviews: None
# ✔️ Porters Lodge Cedar Court — rating: None, reviews: None
# ✔️ twinkboys galore — rating: None, reviews: None
# ✔️ Alpine Villa — rating: None, reviews: None
# ✔️ Ovidio's House — rating: None, reviews: None
# ✔️ AVONNOVA STAYCATION - Luxury Bed and Bath — rating: None, reviews: None
# ✔️ hotel archway — rating: None, reviews: None
# ✔️ Dish is Thai — rating: None, reviews: None
# ✔️ St John’s House — rating: None, reviews: None
# ✔️ Islington 5 bedroom House — rating: None, reviews: None
# ✔️ NapCastle Archway — rating: None, reviews: None
# ✔️ Lyden Court — rating: None, reviews: None
# ✔️ One Two Bedroom Apartments near Holloway Train Station by Belvilla — rating: None, reviews: None
# ✔️ Евгени — rating: None, reviews: None

# %%
# Saving data to mongodb

client = MongoClient("mongodb://localhost:27017/")

db = client["hotel_data"]
collection = db["uk_hotels"]

collection.insert_many(hotels_data)
# Out:
# InsertManyResult([ObjectId('680a65d4543a950c1681c767'), ObjectId('680a65d4543a950c1681c768'), ObjectId('680a65d4543a950c1681c769'), ObjectId('680a65d4543a950c1681c76a'), ObjectId('680a65d4543a950c1681c76b'), ObjectId('680a65d4543a950c1681c76c'), ObjectId('680a65d4543a950c1681c76d'), ObjectId('680a65d4543a950c1681c76e'), ObjectId('680a65d4543a950c1681c76f'), ObjectId('680a65d4543a950c1681c770'), ObjectId('680a65d4543a950c1681c771'), ObjectId('680a65d4543a950c1681c772'), ObjectId('680a65d4543a950c1681c773'), ObjectId('680a65d4543a950c1681c774'), ObjectId('680a65d4543a950c1681c775'), ObjectId('680a65d4543a950c1681c776'), ObjectId('680a65d4543a950c1681c777'), ObjectId('680a65d4543a950c1681c778'), ObjectId('680a65d4543a950c1681c779'), ObjectId('680a65d4543a950c1681c77a'), ObjectId('680a65d4543a950c1681c77b'), ObjectId('680a65d4543a950c1681c77c'), ObjectId('680a65d4543a950c1681c77d'), ObjectId('680a65d4543a950c1681c77e'), ObjectId('680a65d4543a950c1681c77f'), ObjectId('680a65d4543a950c1681c780'), ObjectId('680a65d4543a950c1681c781'), ObjectId('680a65d4543a950c1681c782'), ObjectId('680a65d4543a950c1681c783'), ObjectId('680a65d4543a950c1681c784'), ObjectId('680a65d4543a950c1681c785'), ObjectId('680a65d4543a950c1681c786'), ObjectId('680a65d4543a950c1681c787'), ObjectId('680a65d4543a950c1681c788'), ObjectId('680a65d4543a950c1681c789'), ObjectId('680a65d4543a950c1681c78a'), ObjectId('680a65d4543a950c1681c78b'), ObjectId('680a65d4543a950c1681c78c'), ObjectId('680a65d4543a950c1681c78d'), ObjectId('680a65d4543a950c1681c78e'), ObjectId('680a65d4543a950c1681c78f'), ObjectId('680a65d4543a950c1681c790'), ObjectId('680a65d4543a950c1681c791'), ObjectId('680a65d4543a950c1681c792'), ObjectId('680a65d4543a950c1681c793'), ObjectId('680a65d4543a950c1681c794'), ObjectId('680a65d4543a950c1681c795'), ObjectId('680a65d4543a950c1681c796'), ObjectId('680a65d4543a950c1681c797'), ObjectId('680a65d4543a950c1681c798'), ObjectId('680a65d4543a950c1681c799'), ObjectId('680a65d4543a950c1681c79a'), ObjectId('680a65d4543a950c1681c79b'), ObjectId('680a65d4543a950c1681c79c'), ObjectId('680a65d4543a950c1681c79d'), ObjectId('680a65d4543a950c1681c79e'), ObjectId('680a65d4543a950c1681c79f'), ObjectId('680a65d4543a950c1681c7a0'), ObjectId('680a65d4543a950c1681c7a1'), ObjectId('680a65d4543a950c1681c7a2'), ObjectId('680a65d4543a950c1681c7a3'), ObjectId('680a65d4543a950c1681c7a4'), ObjectId('680a65d4543a950c1681c7a5'), ObjectId('680a65d4543a950c1681c7a6'), ObjectId('680a65d4543a950c1681c7a7'), ObjectId('680a65d4543a950c1681c7a8'), ObjectId('680a65d4543a950c1681c7a9'), ObjectId('680a65d4543a950c1681c7aa'), ObjectId('680a65d4543a950c1681c7ab'), ObjectId('680a65d4543a950c1681c7ac'), ObjectId('680a65d4543a950c1681c7ad'), ObjectId('680a65d4543a950c1681c7ae'), ObjectId('680a65d4543a950c1681c7af'), ObjectId('680a65d4543a950c1681c7b0'), ObjectId('680a65d4543a950c1681c7b1'), ObjectId('680a65d4543a950c1681c7b2'), ObjectId('680a65d4543a950c1681c7b3'), ObjectId('680a65d4543a950c1681c7b4'), ObjectId('680a65d4543a950c1681c7b5'), ObjectId('680a65d4543a950c1681c7b6'), ObjectId('680a65d4543a950c1681c7b7'), ObjectId('680a65d4543a950c1681c7b8'), ObjectId('680a65d4543a950c1681c7b9'), ObjectId('680a65d4543a950c1681c7ba'), ObjectId('680a65d4543a950c1681c7bb'), ObjectId('680a65d4543a950c1681c7bc'), ObjectId('680a65d4543a950c1681c7bd'), ObjectId('680a65d4543a950c1681c7be'), ObjectId('680a65d4543a950c1681c7bf'), ObjectId('680a65d4543a950c1681c7c0'), ObjectId('680a65d4543a950c1681c7c1'), ObjectId('680a65d4543a950c1681c7c2'), ObjectId('680a65d4543a950c1681c7c3'), ObjectId('680a65d4543a950c1681c7c4'), ObjectId('680a65d4543a950c1681c7c5'), ObjectId('680a65d4543a950c1681c7c6'), ObjectId('680a65d4543a950c1681c7c7'), ObjectId('680a65d4543a950c1681c7c8'), ObjectId('680a65d4543a950c1681c7c9'), ObjectId('680a65d4543a950c1681c7ca'), ObjectId('680a65d4543a950c1681c7cb'), ObjectId('680a65d4543a950c1681c7cc'), ObjectId('680a65d4543a950c1681c7cd'), ObjectId('680a65d4543a950c1681c7ce'), ObjectId('680a65d4543a950c1681 ...

# %%
# exporting from mongodb
data = list(collection.find())


for doc in data:
    doc.pop("_id", None)


df = pd.DataFrame(data)
df['category']= 'hotels'
df.to_csv("uk_hotels_from_mongo.csv", index=False)

# %%
#filtering data

input_file = 'uk_hotels_from_mongo.csv'
output_file = 'filtered_hotels.csv'
#which is the parameters i want the remove 
filter_df = df.drop(['place_id', 'longitude', 'latitude'], axis=1, errors='ignore').query('google_rating.notna()').rename(columns={'name': 'hotel_name', 'google_rating': 'google_hotel_rating'})

# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# connection info 
username = "neondb_owner"
password = "npg_C9ksBqFi7RWJ"
host = "ep-black-sun-a4gp6kob-pooler.us-east-1.aws.neon.tech"
database = "neondb"

# SQLAlchemy connction 
engine = create_engine(f'postgresql://neondb_owner:npg_C9ksBqFi7RWJ@ep-black-sun-a4gp6kob-pooler.us-east-1.aws.neon.tech/neondb?sslmode=require')


conn = engine.connect()

# putting data to hotels table 
filter_df.to_sql("hotels",conn, index=False,if_exists='replace')



# reading data  from eon 

df = pd.read_sql("SELECT * FROM hotels;", engine)

events = pd.read_sql("SELECT * FROM event;", engine)

airline= pd.read_sql("SELECT * FROM airlines;", engine)

# %%
combined_df = pd.concat([df, events,airline], ignore_index=True, sort=False)
combined_df
# Out:
#                        hotel_name    city  \
# 0      Antoinette Hotel Wimbledon  London
# 1             The Wimbledon Hotel  London
# 2          Hotel du Vin Wimbledon  London
# 3      The Fox & Grapes Wimbledon  London
# 4               Dog & Fox (Hotel)  London
# ...                           ...     ...
# 15975                         NaN     NaN
# 15976                         NaN     NaN
# 15977                         NaN     NaN
# 15978                         NaN     NaN
# 15979                         NaN     NaN
#
#                                          address  google_hotel_rating  \
# 0                   249-263 The Broadway, London                  4.1
# 1                         78 Worple Road, London                  2.8
# 2      Cannizaro House, West Side Common, London                  4.0
# 3                            9 Camp Road, London                  4.2
# 4               24 High Street Wimbledon, London                  4.2
# ...                                          ...                  ...
# 15975                                        NaN                  NaN
# 15976                                        NaN                  NaN
# 15977                                        NaN                  NaN
# 15978                                        NaN                  NaN
# 15979                                        NaN                  NaN
#
#        google_review_count category event_name location  month  hour  time_ff  \
# 0                    535.0   hotels        NaN      NaN    NaN   NaN      NaN
# 1                    102.0   hotels        NaN      NaN    NaN   NaN      NaN
# 2                    927.0   hotels        NaN      NaN    NaN   NaN      NaN
# 3                    693.0   hotels        NaN      NaN    NaN   NaN      NaN
# 4                   1630.0   hotels        NaN      NaN    NaN   NaN      NaN
# ...                    ...      ...        ...      ...    ...   ...      ...
# 15975                  NaN      NaN        NaN      NaN    NaN   NaN      NaN
# 15976                  NaN      NaN        NaN      NaN    NaN   NaN      NaN
# 15977                  NaN      NaN        NaN      NaN    NaN   NaN      NaN
# 15978                  NaN      NaN        NaN      NaN    NaN   NaN      NaN
# 15979                  NaN      NaN        NaN      NaN    NaN   NaN      NaN
#
#        date_published  date_flown                            route  \
# 0                 NaN         NaN                              NaN
# 1                 NaN         NaN                              NaN
# 2                 NaN         NaN                              NaN
# 3                 NaN         NaN                              NaN
# 4                 NaN         NaN                              NaN
# ...               ...         ...                              ...
# 15975  14th June 2019   June 2019  Phoenix to Amsterdam via London
# 15976   9th June 2019    May 2019              London to Nashville
# 15977   7th June 2019  April 2019                             None
# 15978   7th June 2019   June 2019                             None
# 15979   6th June 2019    May 2019                             None
#
#       type_of_traveller       seat_type  \
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 15975          Business   Economy Class
# 15976      Solo Leisure   Economy Class
# 15977          Business   Economy Class
# 15978              None   Economy Class
# 15979              None  Business Class
#
#                                                  reviews recommended  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 15975  Not Verified |  London to Vancouver. Economy w...          no
# 15976  ✅ Trip Verified |  Phoenix to Amsterdam via Lo...          no
# 15977  ✅ Trip Verified |  Belfast City to Atlanta via...          no
# 15978  ✅ Trip Verified |  Buenos Aires to London. I w...         yes
# 15979  ✅ Trip Verified |  London to Nashville. The wo...          no
#
#                                  header customer_origin
# 0                                   NaN             NaN
# 1                                   NaN             NaN
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                   NaN             NaN
# ...                                 ...             ...
# 15975    "more cramped than I expected"  United Kingdom
# 15976     "cramped seat with no lights"   United States
# 15977          "I might fly them again"   United States
# 15978       "the crew that was so nice"           Spain
# 15979  "my luggage arrived soaking wet"  United Kingdom
#
# [15980 rows x 20 columns]

# %%
combined_df.to_sql("turist_guide",conn, index=False,if_exists='replace')
# Out:
# 980

# %%
# Rating Dist.
fig1 = px.histogram(df, x='google_hotel_rating', nbins=20,
                   title='Hotel Rating Distribution',
                   labels={'google_hotel_rating': 'Rating (1-5)'},
                   color_discrete_sequence=['royalblue'])
fig1.update_layout(yaxis_title='Number of Hotels', plot_bgcolor='white', paper_bgcolor='white')
fig1.show()

# Reviews Dist.
fig2 = px.histogram(df, x='google_review_count', nbins=30,
                   title='Review Count Distribution',
                   labels={'google_review_count': 'Number of Reviews'},
                   color_discrete_sequence=['forestgreen'])
fig2.update_layout(yaxis_title='Count', plot_bgcolor='white', paper_bgcolor='white')
fig2.write_html("review_distribution.html")
fig2.show()

# Rating and reviews graph 
fig3 = px.histogram(df, x='google_hotel_rating', y='google_review_count',
                 title='Rating vs. Review Count',
                 labels={'google_hotel_rating': 'Rating', 'google_review_count': 'Reviews'},
                 color_discrete_sequence=['purple'],
                 opacity=0.5)
fig3.update_layout(plot_bgcolor='white', paper_bgcolor='white')
fig3.show()

fig1.write_html("rating_distribution.html")
fig2.write_html("review_distribution.html")
fig3.write_html("rating_vs_reviews.html")
